# %%
import pandas as pd

# %%
df = pd.read_csv("D:/AIM/MyAuto_ge_Cars_Data.csv")
df.head()
# Out:
#          ID Price ($) Levy ($)   Manufacturer             Model  Prod. year  \
# 0  45568273    11,447      501          HONDA               FIT        2014
# 1  45789427    84,675        -  MERCEDES-BENZ   C 200 7G-TRONIC        2014
# 2  45747002   141,124        -     LAND ROVER  Land Rover Sport        2015
# 3  45786808   219,527        -        BENTLEY    Continental GT        2012
# 4  45816460    30,000        -            BMW           328 F30        2012
#
#     Category Leather interior Fuel type Engine volume    Mileage  Cylinders  \
# 0  Hatchback               No    Petrol           1.5   80000 km        4.0
# 1      Sedan              Yes    Petrol     2.0 Turbo   66500 km        4.0
# 2       Jeep              Yes    Diesel     3.0 Turbo   90000 km        6.0
# 3      Coupe              Yes    Petrol     4.0 Turbo   55500 km        8.0
# 4      Sedan              Yes    Petrol     2.0 Turbo  197000 km        4.0
#
# ...

# %%
df.shape
# Out:
# (80577, 20)

# %%
type(df.Doors)
# Out:
# pandas.core.series.Series

# %%
df.columns
# Out:
# Index(['ID', 'Price ($)', 'Levy ($)', 'Manufacturer', 'Model', 'Prod. year',
#        'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#        'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#        'Interior color', 'Airbags', 'VIN'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80577 entries, 0 to 80576
# Data columns (total 20 columns):
# ID                  80577 non-null int64
# Price ($)           80577 non-null object
# Levy ($)            80577 non-null object
# Manufacturer        80577 non-null object
# Model               80541 non-null object
# Prod. year          80577 non-null int64
# Category            80577 non-null object
# Leather interior    80577 non-null object
# Fuel type           80500 non-null object
# Engine volume       80083 non-null object
# Mileage             80577 non-null object
# Cylinders           80083 non-null float64
# Gear box type       80221 non-null object
# Drive wheels        79650 non-null object
# Doors               78984 non-null object
# Wheel               80577 non-null object
# Color               79136 non-null object
# Interior color      58895 non-null object
# Airbags             80577 non-null int64
# VIN                 43416 non-null object
# ...

# %%
df.ndim
# Out:
# 2

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=80577, step=1),
#  Index(['ID', 'Price ($)', 'Levy ($)', 'Manufacturer', 'Model', 'Prod. year',
#         'Category', 'Leather interior', 'Fuel type', 'Engine volume', 'Mileage',
#         'Cylinders', 'Gear box type', 'Drive wheels', 'Doors', 'Wheel', 'Color',
#         'Interior color', 'Airbags', 'VIN'],
#        dtype='object')]

# %%
df.select_dtypes(include='object')
# Out:
#               Price ($) Levy ($)   Manufacturer                     Model  \
# 0                11,447      501          HONDA                       FIT
# 1                84,675        -  MERCEDES-BENZ           C 200 7G-TRONIC
# 2              1,41,124        -     LAND ROVER          Land Rover Sport
# 3              2,19,527        -        BENTLEY            Continental GT
# 4                30,000        -            BMW                   328 F30
# 5                25,086        -         TOYOTA                     Prius
# 6                 8,000      875         TOYOTA                      Vitz
# 7                 9,700      364         TOYOTA                      Vitz
# 8                   700      875         TOYOTA                      Vitz
# 9                34,184      765  MERCEDES-BENZ                   CLA 250
# 10               25,089     1391  MERCEDES-BENZ                CLS 55 AMG
# 11               18,817        -           FORD                    Escape
# ...

# %%
df.memory_usage()
# Out:
# Index                   80
# ID                  644616
# Price ($)           644616
# Levy ($)            644616
# Manufacturer        644616
# Model               644616
# Prod. year          644616
# Category            644616
# Leather interior    644616
# Fuel type           644616
# Engine volume       644616
# Mileage             644616
# Cylinders           644616
# Gear box type       644616
# Drive wheels        644616
# Doors               644616
# Wheel               644616
# Color               644616
# Interior color      644616
# Airbags             644616
# VIN                 644616
# dtype: int64

# %%
df.empty
# Out:
# False

# %%
df.Doors.value_counts()
# Out:
# 4/5    75497
# 2/3     3059
# >5       428
# Name: Doors, dtype: int64

# %%
df.Doors.unique()
# Out:
# array(['4/5', '2/3', '>5', nan], dtype=object)
