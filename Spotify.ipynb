# %%
# !pip install spotipy
# Out:
# Collecting spotipy
#   Downloading spotipy-2.16.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: requests>=2.20.0 in c:\users\jayita\anaconda3\lib\site-packages (from spotipy) (2.22.0)
# Requirement already satisfied: six>=1.10.0 in c:\users\jayita\anaconda3\lib\site-packages (from spotipy) (1.12.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\jayita\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\jayita\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (1.24.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jayita\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (2019.6.16)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\jayita\anaconda3\lib\site-packages (from requests>=2.20.0->spotipy) (2.8)
# Installing collected packages: spotipy
# Successfully installed spotipy-2.16.1
# WARNING: You are using pip version 20.3.2; however, version 20.3.3 is available.
# You should consider upgrading via the 'c:\users\jayita\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json

# %%
import numpy as np
import pandas as pd

# %%
credentials = json.load(open('authorization.json'))
client_id = credentials['client_id']
client_secret = credentials['client_secret']

# %%
playlist_index = 0
playlists = json.load(open('playlists_like_dislike.json'))
playlist_uri = playlists[playlist_index]['uri']
like = playlists[playlist_index]['like']

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %%
uri = playlist_uri   
username = uri.split(':')[2]
playlist_id = uri.split(':')[4]

# %%
results = sp.user_playlist(username, playlist_id, 'tracks')

# %%
playlist_tracks_data = results['tracks']
playlist_tracks_id = []
playlist_tracks_titles = []
playlist_tracks_artists = []
playlist_tracks_first_artists = []

for track in playlist_tracks_data['items']:
    playlist_tracks_id.append(track['track']['id'])
    playlist_tracks_titles.append(track['track']['name'])
    # adds a list of all artists involved in the song to the list of artists for the playlist
    artist_list = []
    for artist in track['track']['artists']:
        artist_list.append(artist['name'])
    playlist_tracks_artists.append(artist_list)
    playlist_tracks_first_artists.append(artist_list[0])

# %%
features = sp.audio_features(playlist_tracks_id)

# %%
features_df = pd.DataFrame(data=features, columns=features[0].keys())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1095-59758d02661c> in <module>
# ----> 1 features_df = pd.DataFrame(data=features, columns=features[0].keys())
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     433                     if is_named_tuple(data[0]) and columns is None:
#     434                         columns = data[0]._fields
# --> 435                     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     436                     columns = ensure_index(columns)
#     437
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in to_arrays(data, columns, coerce_float, dtype)
#     405     elif isinstance(data[0], compat.Mapping):
#     406         return _list_of_dict_to_arrays(data, columns,
# --> 407                                        coerce_float=coerce_float, dtype=dtype)
#     408     elif isinstance(data[0], ABCSeries):
#     409         return _list_of_series_to_arrays(data, columns,
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in _list_of_dict_to_arrays(data, columns, coerce_float, dtype)
#     475     # assure that they are of the base dict class and not of derived
#     476     # classes
# --> 477     data = [(type(d) is dict) and d or dict(d) for d in data]
#     478
#     479     content = list(lib.dicts_to_array(data, list(columns)).T)
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\construction.py in <listcomp>(.0)
#     475     # assure that they are of the base dict class and not of derived
#     476     # classes
# --> 477     data = [(type(d) is dict) and d or dict(d) for d in data]
#     478
#     479     content = list(lib.dicts_to_array(data, list(columns)).T)
#
# TypeError: 'NoneType' object is not iterable

# %%
features_df['title'] = playlist_tracks_titles
features_df['first_artist'] = playlist_tracks_first_artists
features_df['all_artists'] = playlist_tracks_artists
#features_df = features_df.set_index('id')
features_df = features_df[['id', 'title', 'first_artist', 'all_artists',
                           'danceability', 'energy', 'key', 'loudness',
                           'mode', 'acousticness', 'instrumentalness',
                           'liveness', 'valence', 'tempo',
                           'duration_ms', 'time_signature']]
features_df.tail()

# %%
features_df.to_csv("mint" + ".csv", encoding='utf-8',index="false")

# %%
df = pd.read_csv('playlist.csv')

# %%
df.id.nunique()
# Out:
# 23876

# %%
df.shape
# Out:
# (30528, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27867 entries, 0 to 27866
# Data columns (total 16 columns):
# id                  27867 non-null object
# title               27867 non-null object
# first_artist        27867 non-null object
# all_artists         27867 non-null object
# danceability        27867 non-null float64
# energy              27867 non-null float64
# key                 27867 non-null int64
# loudness            27867 non-null float64
# mode                27867 non-null int64
# acousticness        27867 non-null float64
# instrumentalness    27867 non-null float64
# liveness            27867 non-null float64
# valence             27867 non-null float64
# tempo               27867 non-null float64
# duration_ms         27867 non-null int64
# time_signature      27867 non-null int64
# dtypes: float64(8), int64(4), object(4)
# memory usage: 3.4+ MB

# %%
duplicates = df[df.duplicated('id')]
duplicates
# Out:
#                            id  \
# 106    3tjFYV6RSFtuktYl3ZtYcq
# 117    02kDW379Yfd5PzW5A6vuGt
# 118    5u1n1kITHCxxp8twBcZxWy
# 122    7aGyRfJWtLqgJaZoG9lJhE
# 123    57Z3wNX4RooeGjVyW5HUl9
# 124    59qrUpoplZxbIZxk6X0Bm3
# 127    78qd8dvwea0Gosb6Fe6j3k
# 130    7eJMfftS33KTjuF7lTsMCx
# 131    2b8fOow8UzyDFAE27YhOZM
# 132    62aP9fBQKYKxi7PDXwcUAS
# 135    2qxmye6gAegTMjLKEBoR3d
# 137    1WSGTYKLEpKfNQYYW5Oymt
# 140    62aP9fBQKYKxi7PDXwcUAS
# 150    57kgYKHtte9hLUrjGGuXcx
# 192    709F3MwiVvLD0LQXeKs5Cz
# 194    3cBsEDNhFI9E82vPj3kvi3
# 559    1wiw9ZdiSm3PZfdZqCzb0A
# 828    0rohJsT6NWsThpukt0Xxdc
# 958    1t0vLpJTu4E6Q3R3rDzxQr
# 959    6LuJ3IpHvMANnuzV5NGzrC
# 960    7h3TP14K4trKSjIAX2KdWj
# 961    0B2ILMaXWitHbHAJm2nSLd
# 962    5r9075hPYZN8E7ddE2WoJs
# 963    6MZ4wt0FASXisNMTvh0zmW
# 964    6hj4VrcrOW2oFxUlwda95L
# 965    5XIXFGuVLXEKnq5dks9slW
# 966    6IWNGrWVj9gF4tbVgYkdeJ
# 967    33u11l05Mrc1Pm7bgAwokl
# 968    0jVcDTCdWPPPka66nfuyVu
# 969    4ORqQyhhdSDMSmGYEFn0XX
# ...                       ...
# 30150  0ofHAoxe9vBkTCp2UQIavz
# 30151  2374M0fQpWi3dLnB54qaLX
# 30154  7Ar4G7Ci11gpt6sfH9Cgz5
# 30160  4yugZvBYaoREkJKtbG08Qr
# 30161  4bHsxqR3GMrXTxEPLuK5ue
# 30162  1bp2IO61zbQrbWNmKKxg3f
# 30164  4nXkbcTj3nyww1cHkw5RAP
# 30166  6XUHsYE38CEbYunT983O9G
# 30169  3yrSvpt2l1xhsV9Em88Pul
# 30172  4gvea7UlDkAvsJBPZAd4oB
# 30175  4xh7W7tlNMIczFhupCPniY
# 30183  6zeE5tKyr8Nu882DQhhSQI
# 30184  31H6au3jhblhr6MMJiXnCq
# 30185  72ahyckBJfTigJCFCviVN7
# 30189  5izGeTxueiFX1UPFGohY9w
# 30190  6V50MyHPGhEmwYu0Wdyf0t
# 30197  54eZmuggBFJbV7k248bTTt
# 30201  2olVm1lHicpveMAo4AUDRB
# 30206  7aHRctaQ7vjxVTVmY8OhAA
# 30222  4LFwNJWoj74Yd71fIr1W8x
# 30225  57trQKFZdJxHia4sMJioWk
# 30231  6Zyz8lsnMFpIrCTuvGurCB
# 30237  1QEEqeFIZktqIpPI4jSVSF
# 30238  3Tows9RnoAq9CmMJaII2cO
# 30240  3e0FzZjTXOUtiJGSClOBrI
# 30245  1JLn8RhQzHz3qDqsChcmBl
# 30273  2xBMnos2JHuKgRGr0cSgK5
# 30292  1np1H7mh6iUZhdBhkh3QIo
# 30320  6mHUnQi6NWf1bq2f9GIbH5
# 30347  60lRT01X553ode0LvndRf0
#
#                                                    title  \
# 106                               Mood (feat. iann dior)
# 117                                             Lemonade
# 118                       Holy (feat. Chance The Rapper)
# 122                                        Mad at Disney
# 123                       Stunnin' (feat. Harm Franklin)
# 124                                     Take You Dancing
# 127                                           Boss Bitch
# 130                     death bed (coffee for your head)
# 131                                             Memories
# 132                 ily (i love you baby) (feat. Emilee)
# 135                                   Let Me Down Slowly
# 137    I Can’t Get Enough (benny blanco, Selena Gomez...
# 140                 ily (i love you baby) (feat. Emilee)
# 150                                  Be Okay (with HRVY)
# 192                                                Vibez
# 194                                        Wasted On You
# 559                                        Misunderstood
# 828                    Higher Ground (feat. John Martin)
# 958                                          Il Paradiso
# 959                                    Reminisce Over Us
# 960                                       Time Consuming
# 961                                      For What It Was
# 962                                                Natsu
# 963                                              Aspirin
# 964            Absence of Gravity - Pablo Nouvelle Remix
# 965                                              Ricotta
# 966                          Virudhunagar - Village Live
# 967                                              Routine
# 968                                               Phoebe
# 969                                             Floating
# ...                                                  ...
# 30150                             Dreams - 2004 Remaster
# 30151                                             Africa
# 30154                                Listen to the Music
# 30160                       Take It Easy - 2013 Remaster
# 30161                               Don't Stop Believin'
# 30162                                          The Joker
# 30164                                 Long Train Runnin'
# 30166                                  Give A Little Bit
# 30169                                    Brown Eyed Girl
# 30172                                 The Boys Of Summer
# 30175                    Go Your Own Way - 2004 Remaster
# 30183                                   Dust in the Wind
# 30184      Hungry Eyes - From "Dirty Dancing" Soundtrack
# 30185                                Don't Bring Me Down
# 30189                                   Addicted To Love
# 30190                                      The Way It Is
# 30197                               A Horse with No Name
# 30201                                  The Power Of Love
# 30206                                 We Built This City
# 30222                                 Right Here Waiting
# 30225                                   Sister Christian
# 30231                    New Kid in Town - 2013 Remaster
# 30237                                More Than a Feeling
# 30238                Hard Habit to Break - 2006 Remaster
# 30240                                  Fly Like An Eagle
# 30245        I Want to Know What Love Is - 1999 Remaster
# 30273                                     Gun Metal Grey
# 30292                                       Disco Dancer
# 30320                      I Can't Get Along Without You
# 30347                                          Evolution
#
#                    first_artist  \
# 106                    24kGoldn
# 117              Internet Money
# 118               Justin Bieber
# 122                 salem ilese
# 123               Curtis Waters
# 124                Jason Derulo
# 127                    Doja Cat
# 130                       Powfu
# 131                    Maroon 5
# 132                   Surf Mesa
# 135               Alec Benjamin
# 137                benny blanco
# 140                   Surf Mesa
# 150                       R3HAB
# 192                        ZAYN
# 194               Morgan Wallen
# 559                        OSKA
# 828               Martin Garrix
# 958                       AK420
# 959                  Phlocalyst
# 960                   Snoozegod
# 961                     IAMPAUL
# 962                      lōland
# 963                   Fed Nance
# 964                  Audio Dope
# 965                 Spaze Windu
# 966                       Liphe
# 967                       Cuebe
# 968                       Sátyr
# 969                        Smuv
# ...                         ...
# 30150             Fleetwood Mac
# 30151                      TOTO
# 30154       The Doobie Brothers
# 30160                    Eagles
# 30161                   Journey
# 30162         Steve Miller Band
# 30164       The Doobie Brothers
# 30166                Supertramp
# 30169              Van Morrison
# 30172                Don Henley
# 30175             Fleetwood Mac
# 30183                    Kansas
# 30184               Eric Carmen
# 30185  Electric Light Orchestra
# 30189             Robert Palmer
# 30190             Bruce Hornsby
# 30197                   America
# 30201     Huey Lewis & The News
# 30206                  Starship
# 30222              Richard Marx
# 30225              Night Ranger
# 30231                    Eagles
# 30237                    Boston
# 30238                   Chicago
# 30240         Steve Miller Band
# 30245                 Foreigner
# 30273            The Budos Band
# 30292                 Kiki Gyan
# 30320        Vance and Suzzanne
# 30347                    Magnum
#
#                                              all_artists  danceability  \
# 106                            ['24kGoldn', 'iann dior']         0.700
# 117    ['Internet Money', 'Gunna', 'Don Toliver', 'NAV']         0.799
# 118               ['Justin Bieber', 'Chance the Rapper']         0.673
# 122                                      ['salem ilese']         0.738
# 123                   ['Curtis Waters', 'Harm Franklin']         0.885
# 124                                     ['Jason Derulo']         0.789
# 127                                         ['Doja Cat']         0.707
# 130                             ['Powfu', 'beabadoobee']         0.726
# 131                                         ['Maroon 5']         0.764
# 132                              ['Surf Mesa', 'Emilee']         0.674
# 135                                    ['Alec Benjamin']         0.652
# 137    ['benny blanco', 'Selena Gomez', 'J Balvin', '...         0.541
# 140                              ['Surf Mesa', 'Emilee']         0.674
# 150                                    ['R3HAB', 'HRVY']         0.730
# 192                                             ['ZAYN']         0.635
# 194                                    ['Morgan Wallen']         0.505
# 559                                             ['OSKA']         0.673
# 828                     ['Martin Garrix', 'John Martin']         0.442
# 958                                            ['AK420']         0.754
# 959                          ['Phlocalyst', 'Mr. Käfer']         0.703
# 960                   ['Snoozegod', 'Tibeauthetraveler']         0.757
# 961                                          ['IAMPAUL']         0.829
# 962                                           ['lōland']         0.808
# 963                 ['Fed Nance', 'Golden Ticket Tapes']         0.465
# 964                     ['Audio Dope', 'Pablo Nouvelle']         0.443
# 965                                      ['Spaze Windu']         0.750
# 966                                            ['Liphe']         0.546
# 967                                            ['Cuebe']         0.681
# 968                                            ['Sátyr']         0.494
# 969               ['Smuv', 'Loop Schrauber', '3pmbeatz']         0.721
# ...                                                  ...           ...
# 30150                                  ['Fleetwood Mac']         0.828
# 30151                                           ['TOTO']         0.671
# 30154                            ['The Doobie Brothers']         0.645
# 30160                                         ['Eagles']         0.575
# 30161                                        ['Journey']         0.500
# 30162                              ['Steve Miller Band']         0.596
# 30164                            ['The Doobie Brothers']         0.575
# 30166                                     ['Supertramp']         0.531
# 30169                                   ['Van Morrison']         0.491
# 30172                                     ['Don Henley']         0.516
# 30175                                  ['Fleetwood Mac']         0.586
# 30183                                         ['Kansas']         0.475
# 30184                                    ['Eric Carmen']         0.712
# 30185                       ['Electric Light Orchestra']         0.638
# 30189           ['Robert Palmer', "Eric 'ET' Thorngren"]         0.702
# 30190                     ['Bruce Hornsby', 'The Range']         0.582
# 30197                       ['America', 'George Martin']         0.654
# 30201                          ['Huey Lewis & The News']         0.768
# 30206                                       ['Starship']         0.661
# 30222                                   ['Richard Marx']         0.395
# 30225                                   ['Night Ranger']         0.448
# 30231                                         ['Eagles']         0.649
# 30237                                         ['Boston']         0.377
# 30238                                        ['Chicago']         0.584
# 30240                              ['Steve Miller Band']         0.561
# 30245                                      ['Foreigner']         0.477
# 30273                                 ['The Budos Band']         0.528
# 30292                                      ['Kiki Gyan']         0.699
# 30320                             ['Vance and Suzzanne']         0.751
# 30347                                         ['Magnum']         0.557
#
#        energy  key  loudness  mode  acousticness  instrumentalness  liveness  \
# 106     0.722    7    -3.558     0      0.221000          0.000000    0.2720
# 117     0.660    1    -6.153     0      0.256000          0.000000    0.1110
# 118     0.704    6    -8.056     1      0.196000          0.000000    0.0898
# 122     0.621    0    -7.313     1      0.424000          0.000007    0.6920
# 123     0.685   11    -6.429     0      0.330000          0.000000    0.1480
# 124     0.711    2    -4.248     1      0.033200          0.000000    0.0876
# 127     0.955   10    -4.593     0      0.127000          0.000000    0.2020
# 130     0.431    8    -8.765     0      0.731000          0.000000    0.6960
# 131     0.320   11    -7.209     1      0.837000          0.000000    0.0822
# 132     0.774   11    -7.567     0      0.068600          0.001880    0.3930
# 135     0.557    1    -5.714     0      0.740000          0.000000    0.1240
# 137     0.468   10    -4.039     0      0.404000          0.000004    0.3580
# 140     0.774   11    -7.567     0      0.068600          0.001880    0.3930
# 150     0.558    8    -6.535     1      0.017900          0.000000    0.1280
# 192     0.659    7    -7.499     1      0.242000          0.028500    0.1050
# 194     0.657   11    -5.240     0      0.373000          0.001070    0.1260
# 559     0.199    4   -12.351     0      0.855000          0.000020    0.3600
# 828     0.619    1    -5.280     1      0.084100          0.000000    0.0889
# 958     0.385   10   -10.182     1      0.010500          0.873000    0.0840
# 959     0.306    8   -10.919     1      0.280000          0.901000    0.1160
# 960     0.461    1    -9.477     0      0.265000          0.123000    0.3500
# 961     0.329    1   -11.067     0      0.656000          0.894000    0.1160
# 962     0.574    8    -7.862     0      0.647000          0.552000    0.1300
# 963     0.403    5    -7.312     0      0.927000          0.818000    0.1050
# 964     0.253    3   -13.694     0      0.770000          0.565000    0.2870
# 965     0.337    6   -12.862     0      0.240000          0.237000    0.2920
# 966     0.372    5    -9.149     1      0.134000          0.017200    0.2700
# 967     0.486    2    -8.481     0      0.429000          0.539000    0.1360
# 968     0.476    1   -13.002     0      0.604000          0.926000    0.0895
# 969     0.266    9   -13.768     0      0.127000          0.949000    0.1170
# ...       ...  ...       ...   ...           ...               ...       ...
# 30150   0.492    0    -9.744     1      0.064400          0.004280    0.1280
# 30151   0.373    9   -18.064     1      0.257000          0.000080    0.0481
# 30154   0.598    1   -13.180     0      0.221000          0.000004    0.0721
# 30160   0.670    7   -10.390     1      0.343000          0.000005    0.1290
# 30161   0.748    4    -9.072     1      0.127000          0.000000    0.4470
# 30162   0.448    5    -9.616     1      0.365000          0.000005    0.2060
# 30164   0.912    7    -7.275     0      0.091600          0.002110    0.0562
# 30166   0.818    2    -5.358     1      0.069400          0.009600    0.2630
# 30169   0.583    7   -10.964     1      0.182000          0.000000    0.4070
# 30172   0.549    6   -13.741     1      0.501000          0.005720    0.1840
# 30175   0.941    5    -5.139     1      0.016700          0.000776    0.0680
# 30183   0.322    7   -10.687     1      0.367000          0.000560    0.1100
# 30184   0.549    5    -9.484     1      0.011000          0.000000    0.1180
# 30185   0.867    2    -6.469     1      0.144000          0.000733    0.0846
# 30189   0.578    2   -13.415     1      0.382000          0.000006    0.0425
# 30190   0.689    7   -12.203     1      0.607000          0.057100    0.1450
# 30197   0.506   11   -17.180     0      0.686000          0.015500    0.1550
# 30201   0.829    5    -5.109     1      0.096400          0.000029    0.0970
# 30206   0.908    5    -4.897     1      0.052000          0.000000    0.0708
# 30222   0.252    0   -13.589     1      0.800000          0.000000    0.1010
# 30225   0.350    5   -16.239     1      0.147000          0.000002    0.0842
# 30231   0.425    4    -9.811     1      0.378000          0.001300    0.1080
# 30237   0.682    7    -8.039     1      0.000894          0.002170    0.0504
# 30238   0.612    2    -5.833     1      0.448000          0.000000    0.1710
# 30240   0.754    9   -12.769     0      0.610000          0.019400    0.3280
# 30245   0.471    6   -10.036     1      0.193000          0.000002    0.1310
# 30273   0.773    4    -6.119     0      0.000505          0.881000    0.1340
# 30292   0.869    9   -10.199     1      0.031700          0.411000    0.0368
# 30320   0.752    9    -6.545     0      0.411000          0.000661    0.1000
# 30347   0.835    8    -9.570     0      0.824000          0.379000    0.1110
#
#        valence    tempo  duration_ms  time_signature
# 106      0.756   90.989       140526               4
# 117      0.471  140.040       195429               4
# 118      0.372   86.919       212093               4
# 122      0.715  113.968       136839               4
# 123      0.937   99.954       144000               4
# 124      0.753  112.985       190306               4
# 127      0.575  125.989       134240               4
# 130      0.348  144.026       173333               4
# 131      0.575   91.019       189486               4
# 132      0.330  112.050       176547               4
# 135      0.483  150.073       169354               4
# 137      0.690   95.266       158027               4
# 140      0.330  112.050       176547               4
# 150      0.618  100.066       141600               4
# 192      0.340   96.855       163127               4
# 194      0.252  196.000       178520               3
# 559      0.228  123.038       198049               4
# 828      0.382  128.318       206279               4
# 958      0.527  176.014       183476               4
# 959      0.473   86.022       156977               4
# 960      0.353  108.999       115518               4
# 961      0.669   87.011       157064               4
# 962      0.905   99.986       156000               4
# 963      0.610   79.787       100185               4
# 964      0.252   82.977       217867               4
# 965      0.717   86.115       146000               4
# 966      0.247  123.952       254265               4
# 967      0.226   86.917       169170               4
# 968      0.271   88.900       145204               4
# 969      0.795   85.180       124235               4
# ...        ...      ...          ...             ...
# 30150    0.789  120.151       257800               4
# 30151    0.732   92.718       295893               4
# 30154    0.913  105.929       227267               4
# 30160    0.740  139.191       211578               4
# 30161    0.514  118.852       250987               4
# 30162    0.796   83.293       264504               4
# 30164    0.843  117.399       207267               4
# 30166    0.471   90.767       248173               4
# 30169    0.907  150.572       183307               4
# 30172    0.907  176.941       288733               4
# 30175    0.831  135.448       223613               4
# 30183    0.387   93.503       206267               4
# 30184    0.552  109.882       251067               4
# 30185    0.805  115.692       243373               4
# 30189    0.975  111.617       363640               4
# 30190    0.531  111.166       297853               4
# 30197    0.831  123.179       252240               4
# 30201    0.962  118.773       234333               4
# 30206    0.656  144.091       296080               4
# 30222    0.126  177.679       264333               4
# 30225    0.234  177.279       302933               4
# 30231    0.651  107.383       304926               4
# 30237    0.288  108.736       285133               4
# 30238    0.402   81.182       283733               4
# 30240    0.642  100.080       282693               4
# 30245    0.423   81.204       304787               4
# 30273    0.398   97.682       196747               4
# 30292    0.963  115.273       416800               4
# 30320    0.850  111.158       400000               4
# 30347    0.760  106.848       350600               4
#
# [6613 rows x 16 columns]
