# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("reviews-res.csv")
df.head()
# Out:
#    Unnamed: 0           business_index      business_name        date  \
# 0           0  The Cuckoos Nest Albany  The Cuckoo’s Nest  22-07-2020
# 1           1  The Cuckoos Nest Albany  The Cuckoo’s Nest  13-08-2020
# 2           2  The Cuckoos Nest Albany  The Cuckoo’s Nest  28-06-2020
# 3           3  The Cuckoos Nest Albany  The Cuckoo’s Nest  26-04-2020
# 4           4  The Cuckoos Nest Albany  The Cuckoo’s Nest  30-08-2020
#
#    pic_count                                           pic_urls  \
# 0          0                                                 []
# 1          0                                                 []
# 2          3  ['https://s3-media2.fl.yelpcdn.com/bphoto/Jiq3...
# 3          3  ['https://s3-media3.fl.yelpcdn.com/bphoto/11Wc...
# 4          0                                                 []
#
#                                               review  star_rating  polarity
# 0  #GRITS know best! So take it from this one, th...            5  0.375949
# ...

# %%
df.shape
# Out:
# (24345, 9)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'business_index', 'business_name', 'date', 'pic_count',
#        'pic_urls', 'review', 'star_rating', 'polarity'],
#       dtype='object')

# %%
type(df.date)
# Out:
# pandas.core.series.Series

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df["date"].dt.year.unique()
# Out:
# array([2020, 2021, 2019, 2018, 2017, 2016, 2015, 2014, 2013], dtype=int64)

# %%
type(df["date"].dt.year)
# Out:
# pandas.core.series.Series

# %%
df["date"].dt.year.value_counts()
# Out:
# 2018    3934
# 2017    3788
# 2016    3650
# 2015    3430
# 2020    3155
# 2019    2716
# 2014    2183
# 2013    1482
# 2021       7
# Name: date, dtype: int64

# %%
if df.iloc[292]["date"].year == 2019:
    print(df.iloc[292]["date"])
# Out:
# 2019-03-29 00:00:00

# %%
from datetime import datetime
dt = datetime.now()
print(dt)
# Out:
# 2021-01-25 16:39:31.872684

# %%
from datetime import datetime
dt = datetime.now()
for i in df.index:
    if df.loc[i,"date"].year == 2005 or df.loc[i,"date"].year == 2006 or df.loc[i,"date"].year == 2007 or df.loc[i,"date"].year == 2008 or df.loc[i,"date"].year == 2009 or df.loc[i,"date"].year == 2010:
        df.loc[i,"date"] = df.loc[i,"date"].replace(year = 2020)
        #print(df.loc[i,"date"])

# %%
for i in df.index:
    if df.loc[i,"date"].year == 2011 or df.loc[i,"date"].year == 2012:
        df.loc[i,"date"] = df.loc[i,"date"].replace(year = 2020)

# %%
df.to_csv("reviews-res.csv")

# %%
for i in df.index:
    if df.loc[i,"date"].year == 2021:
        print(df.loc[i,"date"])
# Out:
# 2021-01-18 00:00:00
# 2021-01-24 00:00:00
# 2021-01-07 00:00:00
# 2021-01-20 00:00:00
# 2021-01-13 00:00:00
# 2021-01-01 00:00:00
# 2021-01-24 00:00:00

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24345 entries, 0 to 24344
# Data columns (total 9 columns):
# Unnamed: 0        24345 non-null int64
# business_index    24345 non-null object
# business_name     24345 non-null object
# date              24345 non-null object
# pic_count         24345 non-null int64
# pic_urls          24345 non-null object
# review            24345 non-null object
# star_rating       24345 non-null int64
# polarity          24345 non-null float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.7+ MB

# %%
df.select_dtypes(exclude = "object")
# Out:
#        Unnamed: 0  pic_count  star_rating  polarity
# 0               0          0            5  0.375949
# 1               1          0            4  0.198864
# 2               2          3            5  0.273571
# 3               3          3            5  0.190196
# 4               4          0            5  0.160985
# 5               5          3            5  0.177879
# 6               6          3            5  0.211345
# 7               7          3            5  0.287500
# 8               8          1            5  0.438571
# 9               9          1            5  0.277778
# 10             10          3            5  0.371053
# 11             11          0            5  0.256481
# 12             12          2            1  0.085833
# 13             13          0            5  0.266667
# 14             14          3            5  0.161053
# 15             15          0            5  0.409167
# 16             16          3            4  0.426250
# ...
