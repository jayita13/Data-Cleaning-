# %%
import pandas as pd
import numpy as np
import re

# %%
df = pd.read_csv('C:/Users/Jayita/Desktop/makemytrip_com-travel.csv')
df.head()
# Out:
#                             Uniq Id  \
# 0  0eaaee0a8a6ba47cfc9f6e6852fcf9f0
# 1  c782c902e6d370153361d708bb2bca64
# 2  1087ed9303d0ac724460088a5920065d
# 3  3bda4788836d573910f605154ba949dc
# 4  aab612682c998bde97e040b212cd5689
#
#                                         Package Name  \
# 0       A Grand Week in North East - Lachung Special
# 1  A Relaxing holiday to Kerala - Free Speed Boat...
# 2  Experiential Manali from Chandigarh (Candid Ph...
# 3                           Stunning Kashmir Holiday
# 4        Best of Holiday in Himachal from Chandigarh
#
#                                             Page Url Package Type     Company  \
# 0  https://holidayz.makemytrip.com/holidays/india...       Deluxe  Makemytrip
# 1  https://holidayz.makemytrip.com/holidays/india...     Standard  Makemytrip
# 2  https://holidayz.makemytrip.com/holidays/india...       Deluxe  Makemytrip
# 3  https://holidayz.makemytrip.com/holidays/india...     Standard  Makemytrip
# ...

# %%
df.iloc[29990:]
# Out:
#                                 Uniq Id  \
# 29990  f0d72e38a99aea947e1ca1a3d0427444
# 29991  b52298a2153163691288d9c716145f52
# 29992  1f3bca428ba534a212d4ed03a12ffda2
# 29993  046d75c695e9479979ace7c9d7f71e68
# 29994  14ee6a74a9a7b3aad64b6f81118b3d8f
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29996  2f8b72d6321a705e6a701c01881208bc
# 29997  1e7109a6ebab2470a9561517b326e741
# 29998  4eb294e442c0c893736f35aa23c5683d
# 29999  77179df7596ed97c7d22a53fc5bcda2c
#
#                                             Package Name  \
# 29990                       Mystical Himachal from Delhi
# 29991  Rajasthan Holiday with Dinner at a Lake View H...
# 29992                       Andaman and Havelock Special
# 29993   Dalhousie getaway from Chandigarh (with Flights)
# 29994              Holiday In Kuala Lumpur With LEGOLAND
# 29995  Mewar Special - Horse Riding & Private Sunset ...
# 29996                  A short trip to Cochin and Munnar
# ...

# %%
df.shape
# Out:
# (30000, 19)

# %%
df.columns
# Out:
# Index(['Uniq Id', 'Package Name', 'Page Url', 'Package Type', 'Company',
#        'Destination', 'Itinerary', 'Places Covered', 'Travel Date',
#        'Hotel Details', 'Start City', 'Airline', 'Flight Stops',
#        'Onwards Return Flight Time', 'Meals', 'Price Per Two Persons',
#        'Per Person Price', 'Sightseeing Places Covered', 'Cancellation Rules'],
#       dtype='object')

# %%
df['Package Type'].unique()
# Out:
# array(['Deluxe', 'Standard', 'Premium', 'Luxury', 'Budget'], dtype=object)

# %%
val = pd.Series(df['Page Url']).str.startswith('https')
i = 0
for n in num:
    if n == True:
        print(i,n)
    i+=1
# Out:
# 0 True
# 1 True
# 2 True
# 3 True
# 4 True
# 5 True
# 6 True
# 7 True
# 8 True
# 9 True
# 10 True
# 11 True
# 12 True
# 13 True
# 14 True
# 15 True
# 16 True
# 17 True
# 18 True
# 19 True
# 20 True
# 21 True
# 22 True
# 23 True
# 24 True
# 25 True
# 26 True
# 27 True
# 28 True
# 29 True
# 30 True
# 31 True
# 32 True
# 33 True
# 34 True
# 35 True
# 36 True
# 37 True
# 38 True
# 39 True
# 40 True
# 41 True
# 42 True
# 43 True
# 44 True
# 45 True
# 46 True
# 47 True
# 48 True
# 49 True
# 50 True
# 51 True
# 52 True
# 53 True
# 54 True
# 55 True
# 56 True
# 57 True
# 58 True
# 59 True
# 60 True
# 61 True
# 62 True
# 63 True
# 64 True
# 65 True
# 66 True
# 67 True
# 68 True
# 69 True
# 70 True
# 71 True
# 72 True
# 73 True
# 74 True
# 75 True
# 76 True
# 77 True
# 78 True
# 79 True
# 80 True
# 81 True
# 82 True
# 83 True
# 84 True
# 85 True
# 86 True
# 87 True
# 88 True
# 89 True
# 90 True
# 91 True
# 92 True
# 93 True
# 94 True
# 95 True
# 96 True
# 97 True
# 98 True
# 99 True
# ...

# %%
num = pd.Series(df['Page Url']).str.startswith('https')
i = 0
for n in num:
    if n == False:
        df.loc[i,'Hotel Details'] = df.loc[i,'Page Url']
        #print(i,n)
    i+=1

# %%
pt = pd.Series(df['Package Type']).str.startswith('https')
i = 0
for n in pt:
    if n == True:
        df.loc[i,'Page Url'] = df.loc[i,'Package Type']
        #print(i,n)
    i+=1

# %%
com = pd.Series(df['Company']).str.startswith('Makemytrip')
i = 0
for n in com:
    if n == False:
        df.loc[i,'Package Type'] = df.loc[i,'Company']
        #print(i,n)
    i+=1

# %%
com = pd.Series(df['Destination']).str.startswith('Makemytrip')
i = 0
for n in com:
    if n == True:
        df.loc[i,'Company'] = df.loc[i,'Destination']
        #print(i,n)
    i+=1

# %%
com = pd.Series(df['Destination']).str.startswith('Makemytrip')
i = 0
for n in com:
    if n == True:
        df.loc[i,'Destination'] = df.loc[i,'Itinerary']
        #print(i,n)
    i+=1

# %%
com = pd.Series(df['Itinerary']).str.contains('\\d',regex=True)
i = 0
for n in com:
    if n == False:
        df.loc[i,'Itinerary'] = df.loc[i,'Places Covered']
        #print(i,n)
    i+=1

# %%
com = pd.Series(df['Places Covered']).str.contains('\\d',regex=True)
i = 0
for n in com:
    if n == True:
        df.loc[i,'Places Covered'] = df.loc[i,'Travel Date']
        #print(i,n)
    i+=1

# %%
df.iloc[29990:]
# Out:
#                                 Uniq Id  \
# 29990  f0d72e38a99aea947e1ca1a3d0427444
# 29991  b52298a2153163691288d9c716145f52
# 29992  1f3bca428ba534a212d4ed03a12ffda2
# 29993  046d75c695e9479979ace7c9d7f71e68
# 29994  14ee6a74a9a7b3aad64b6f81118b3d8f
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29996  2f8b72d6321a705e6a701c01881208bc
# 29997  1e7109a6ebab2470a9561517b326e741
# 29998  4eb294e442c0c893736f35aa23c5683d
# 29999  77179df7596ed97c7d22a53fc5bcda2c
#
#                                             Package Name  \
# 29990                       Mystical Himachal from Delhi
# 29991  Rajasthan Holiday with Dinner at a Lake View H...
# 29992                       Andaman and Havelock Special
# 29993   Dalhousie getaway from Chandigarh (with Flights)
# 29994              Holiday In Kuala Lumpur With LEGOLAND
# 29995  Mewar Special - Horse Riding & Private Sunset ...
# 29996                  A short trip to Cochin and Munnar
# ...

# %%
df.to_csv('travel_updated.csv')

# %%
df1 = pd.read_csv('travel_updated.csv')

# %%
df1.columns
# Out:
# Index(['Uniq Id', 'Package Name', 'Page Url', 'Package Type', 'Company',
#        'Destination', 'Itinerary', 'Places Covered', 'Travel Date',
#        'Hotel Details', 'Start City', 'Airline', 'Flight Stops',
#        'Onwards Return Flight Time', 'Meals', 'Price Per Two Persons',
#        'Per Person Price', 'Sightseeing Places Covered', 'Cancellation Rules'],
#       dtype='object')

# %%
df1['Flight Stops'].value_counts()
# Out:
# Series([], Name: Flight Stops, dtype: int64)

# %%
df1['Package Type'].value_counts()
# Out:
# Deluxe      8499
# Standard    8171
# Premium     7960
# Luxury      4688
# Budget       682
# Name: Package Type, dtype: int64

# %%
for index in df1.index:
    if df1.loc[index,'Package Type'] == 'Budget':
        df1.loc[index, 'Flight Stops'] = 2
        df1.loc[index, 'Meals'] = 2
    if df1.loc[index,'Package Type'] == 'Standard':
        df1.loc[index, 'Flight Stops'] = 2
        df1.loc[index, 'Meals'] = 3
    if df1.loc[index,'Package Type'] == 'Deluxe':
        df1.loc[index, 'Flight Stops'] = 1
        df1.loc[index, 'Meals'] = 3
    if df1.loc[index,'Package Type'] == 'Luxury':
        df1.loc[index, 'Flight Stops'] = 0
        df1.loc[index, 'Meals'] = 4
    if df1.loc[index,'Package Type'] == 'Premium':
        df1.loc[index, 'Flight Stops'] = 0
        df1.loc[index, 'Meals'] = 5

# %%
df1['Flight Stops'].value_counts()
# Out:
# 0.0    12648
# 2.0     8853
# 1.0     8499
# Name: Flight Stops, dtype: int64

# %%
df1['Meals'].value_counts()
# Out:
# 3.0    16670
# 5.0     7960
# 4.0     4688
# 2.0      682
# Name: Meals, dtype: int64

# %%
df1.head()
# Out:
#                             Uniq Id  \
# 0  0eaaee0a8a6ba47cfc9f6e6852fcf9f0
# 1  c782c902e6d370153361d708bb2bca64
# 2  1087ed9303d0ac724460088a5920065d
# 3  3bda4788836d573910f605154ba949dc
# 4  aab612682c998bde97e040b212cd5689
#
#                                         Package Name  \
# 0       A Grand Week in North East - Lachung Special
# 1  A Relaxing holiday to Kerala - Free Speed Boat...
# 2  Experiential Manali from Chandigarh (Candid Ph...
# 3                           Stunning Kashmir Holiday
# 4        Best of Holiday in Himachal from Chandigarh
#
#                                             Page Url Package Type     Company  \
# 0  https://holidayz.makemytrip.com/holidays/india...       Deluxe  Makemytrip
# 1  https://holidayz.makemytrip.com/holidays/india...     Standard  Makemytrip
# 2  https://holidayz.makemytrip.com/holidays/india...       Deluxe  Makemytrip
# 3  https://holidayz.makemytrip.com/holidays/india...     Standard  Makemytrip
# ...

# %%
df1.to_csv('travel-updated.csv')

# %%
print(type(df1['Travel Date']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df1['Uniq Id'].nunique()
# Out:
# 30000
